# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
path = '/content/drive/MyDrive/project'
os.chdir(path)

# %%
# !ls
# Out:
# colab_train_tiny_imagenet_script.ipynb	tiny_imagenet_distill_script.py
# imagenet_class_index.json		training_curves_10.png
# tiny_imagenet_checkpoint_epoch_10	training_curves_5.png
# tiny_imagenet_checkpoint_epoch_5

# %%
# !python3 tiny_imagenet_distill_script.py --epochs 10 --lr 0.001 --resume_train ./tiny_imagenet_checkpoint_epoch_10/ --resume_epochs_from 10
# Out:
# 2025-12-18 20:08:56.316436: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766088536.348663    1796 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766088536.358784    1796 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766088536.384922    1796 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

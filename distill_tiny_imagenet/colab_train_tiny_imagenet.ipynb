# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
path = '/content/drive/MyDrive/project'
os.chdir(path)

# %%
# !ls
# Out:
# colab_train_tiny_imagenet_script.ipynb	tiny_imagenet_distill_script.py
# imagenet_class_index.json

# %%
# !python3 tiny_imagenet_distill_script.py --epochs 20 --lr 0.002
# Out:
# 2025-12-18 05:40:00.796015: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766036400.815966     573 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766036400.821841     573 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766036400.837074     573 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
